# %%
from sympy import *
init_printing()
from IPython.display import display, Latex, HTML, Math
import numpy as np
#need to import Rational because otherwise will not show/calculate fractionas and will convert to decimal
from sympy import Rational as R

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
u1 = Matrix([[1],[2],[1],[1]])
u2 = Matrix([[-2],[1],[-1],[1]])
u3 = Matrix([[1],[1],[-2],[-1]])
u4 = Matrix([[-1],[1],[1],[-1]])

v = Matrix([[4],[2],[-1],[0]])
#a)

U = Matrix.hstack(u1,u2,u3,u4)
U.T * U , U.rref()
# Out:
# ⎛⎡7  0  0   1 ⎤  ⎛⎡1  0  0  0⎤              ⎞⎞
# ⎜⎢            ⎥  ⎜⎢          ⎥              ⎟⎟
# ⎜⎢0  7  0   1 ⎥  ⎜⎢0  1  0  0⎥              ⎟⎟
# ⎜⎢            ⎥, ⎜⎢          ⎥, (0, 1, 2, 3)⎟⎟
# ⎜⎢0  0  7   -1⎥  ⎜⎢0  0  1  0⎥              ⎟⎟
# ⎜⎢            ⎥  ⎜⎢          ⎥              ⎟⎟
# ⎝⎣1  1  -1  4 ⎦  ⎝⎣0  0  0  1⎦              ⎠⎠

# %%
# indepedent, not orthogonal
v1,v2,v3,v4 = GramSchmidt((u1,u2,u3,u4))

# %%
z1 = v.project(v1) + v.project(v2)
z2 = v.project(v3) + v.project(v4)

z1,z2
# Out:
# ⎛⎡17/7⎤  ⎡11/7 ⎤⎞
# ⎜⎢    ⎥  ⎢     ⎥⎟
# ⎜⎢9/7 ⎥  ⎢ 5/7 ⎥⎟
# ⎜⎢    ⎥, ⎢     ⎥⎟
# ⎜⎢12/7⎥  ⎢-19/7⎥⎟
# ⎜⎢    ⎥  ⎢     ⎥⎟
# ⎝⎣2/7 ⎦  ⎣-2/7 ⎦⎠
